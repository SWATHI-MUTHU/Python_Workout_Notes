# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATHI-MUTHU/Python_Workout_Notes/blob/main/Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas
import pandas as pd

# %%
dm=pd.read_csv("/content/services (1).csv")

# %%
dm.head()

# %%
dm.tail()

# %%
dm.sample()

# %%
dm.sample()

# %%
dm.sample(5)

# %%
dm.head(20)

# %%
dm.columns

# %%
dm.dtypes

# %%
dm.info()

# %%
dm["location_id"]

# %%
dm[["location_id","email"]]

# %%
dm.isnull()

# %%
dm.isnull().sum()
# Out:
# id                          0
# location_id                 0
# program_id                 23
# accepted_payments          22
# alternate_name             22
# application_process         0
# audience                    9
# description                 0
# eligibility                 6
# email                      22
# fees                        2
# funding_sources             2
# interpretation_services    22
# keywords                    2
# languages                  22
# name                        0
# required_documents         22
# service_areas               2
# status                      0
# wait_time                   4
# website                    21
# taxonomy_ids               22
# dtype: int64

# %%
dm.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# dtype: bool

# %%
dm.duplicated().sum()
# Out:
# 0

# %%
dm.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-ea8415b8a3ee> in <cell line: 1>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
dt=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
dt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dt.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dt.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dt.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
obj=dt.dtypes=="object"

# %%
dt.dtypes[obj].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
dt["PassengerId"][50:60]
# Out:
# 50    51
# 51    52
# 52    53
# 53    54
# 54    55
# 55    56
# 56    57
# 57    58
# 58    59
# 59    60
# Name: PassengerId, dtype: int64

# %%
dt[["Name","Ticket"]]
# Out:
#                                                   Name            Ticket
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
# [891 rows x 2 columns]

# %%
#craete new column:
dt["new_col"]=0

# %%
dt["new_col"]=dt["Name"]+dt["Ticket"]

# %%
dt.sample()
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 363          364         0       3  Asim, Mr. Adola  male  35.0      0      0
#
#                  Ticket  Fare Cabin Embarked  \
# 363  SOTON/O.Q. 3101310  7.05   NaN        S
#
#                                new_col
# 363  Asim, Mr. AdolaSOTON/O.Q. 3101310

# %%
age=(dt["Age"]>18)

# %%
dt[age]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
fare_30=dt["Fare"]>30

# %%
dt[fare_30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 13            14         0       3
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
(dt["Age"]>18)&(dt["Sex"]=="Female")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
dt[(dt["Age"]>18)&(dt["Sex"]=="Male")]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, new_col]
# Index: []

# %%
dt['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
max_fare=max(dt["Fare"])

# %%
dt["Fare"]==max_fare
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
dt[dt["Fare"]==max_fare]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
min_fare=min(dt["Fare"])

# %%
dt["Fare"]==min_fare
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
dt[dt["Fare"]==min_fare]["Name"]
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
dt["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
dt["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dt["Sex"].nunique()
# Out:
# 2

# %%
d={
    "key1":[1,2,3,4],
    "key2":[4,5,6,7],
    "key3":[7,8,9,10]
}

# %%
d
# Out:
# {'key1': [1, 2, 3, 4], 'key2': [4, 5, 6, 7], 'key3': [7, 8, 9, 10]}

# %%
type(d)
# Out:
# dict

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3     4     7    10

# %%
dt.drop('Sex',axis= 1 ,inplace=True)

# %%
dt.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dt.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch            Ticket  \
# 0            1         0       3  22.0      1      0         A/5 21171
# 1            2         1       1  38.0      1      0          PC 17599
# 2            3         1       3  26.0      0      0  STON/O2. 3101282
# 3            4         1       1  35.0      1      0            113803
# 4            5         0       3  35.0      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %%
dt.drop(2,inplace=True)

# %%
dt.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Ticket     Fare  \
# 0            1         0       3  22.0      1      0  A/5 21171   7.2500
# 1            2         1       1  38.0      1      0   PC 17599  71.2833
# 4            5         0       3  35.0      0      0     373450   8.0500
# 5            6         0       3   NaN      0      0     330877   8.4583
# 6            7         0       1  54.0      0      0      17463  51.8625
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 4   NaN        S
# 5   NaN        Q
# 6   E46        S

# %%
dt.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          686
# Embarked         2
# dtype: int64

# %%
dt.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          686
# Embarked         2
# dtype: int64

# %%
# Total fare paid by survived and not survived
dt.groupby("Survived").sum()["Fare"]
# Out:
# Survived
# 0    12142.7199
# 1    16490.2044
# Name: Fare, dtype: float64

# %%
# fillna()
mean_age=dt["Age"].mean()
mean_age
# Out:
# 29.696867977528086

# %%
dt["Age"].fillna(mean_age)
# Out:
# 0      22.000000
# 1      38.000000
# 4      35.000000
# 5      29.696868
# 6      54.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.696868
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64

# %%
dt.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          686
# Embarked         2
# dtype: int64

# %%
#concat -Merging 2 row table
dt1=dt[["Age","Survived"]][1:5]
dt2=dt[["Age","Survived"]][6:10]

# %%
dt1
# Out:
#     Age  Survived
# 1  38.0         1
# 2  26.0         1
# 3  35.0         1
# 4  35.0         0

# %%
dt2
# Out:
#     Age  Survived
# 6  54.0         0
# 7   2.0         0
# 8  27.0         1
# 9  14.0         1

# %%
ds=pd.concat([dt1,dt2])
ds
# Out:
#     Age  Survived
# 1  38.0         1
# 2  26.0         1
# 3  35.0         1
# 4  35.0         0
# 6  54.0         0
# 7   2.0         0
# 8  27.0         1
# 9  14.0         1

# %%
#apply()
def inr_con(a):
  return a*30

# %%
dt["inr_fare"]=dt["Fare"].apply(inr_con)

# %%
dt.sample()
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 225          226         0       3  Berglund, Mr. Karl Ivar Sven  male  22.0
#
#      SibSp  Parch   Ticket  Fare Cabin Embarked  inr_fare
# 225      0      0  PP 4348  9.35   NaN        S     280.5

# %%
def train(s):
  if s<10:
    return "class3"
  elif 10<s<20:
    return "class2"
  else:
     return "class1"

# %%
dt["train_fare"]=dt["Fare"].apply(train)

# %%
dt.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a5c496b8dfc> in <cell line: 1>()
# ----> 1 dt.head(50)
#
# NameError: name 'dt' is not defined

# %%
#Merge
d2={"key1":[1,2,45,6,67],
    "Key4":[56,5,6,7,8],
    "Key5":[3,56,5,6,6]
    }
data2=pd.DataFrame(d2)

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]
})

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  Key4  Key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6
